# %% [markdown]
# # Image Classification with CNN using Keras

# %% [markdown]
# # Task 1: Import Libraries

# %%
import tensorflow as tf
import os
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

if not os.path.isdir('models'):
    os.mkdir('models')
    
print('TensorFlow version:', tf.__version__)
print('Is using GPU?', tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.0.1
# Is using GPU? False

# %% [markdown]
# # Task 2: Preprocess Data

# %% [markdown]
# CIFAR-10 dataset contains 60000 training ex. and 10 classes and 10000 ex in test set
# in order to speed up we are using 3 classes and 15000 ex in training set.

# %%
def get_three_classes(x, y):
    
#   select only 3 classes
    indices_0, _ = np.where(y == 0.)
    indices_1, _ = np.where(y == 1.)
    indices_2, _ = np.where(y == 2.)

#   concatenate the indices
    indices = np.concatenate([indices_0, indices_1, indices_2], axis=0)
    
#   select examples and labels which corresponds to these indices
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
#   shuffle the indices and to not repeat the item make replace False
#   syntax = (range of numbers to choose to fill the array, size of the array)
    indices = np.random.choice(range(count), count, replace=False)
#   Now, indices are completely random and unique
    
    x = x[indices]
    y = y[indices]
    
#   one hot encoded
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
# testing above function

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, y_train = get_three_classes(x_train, y_train)
x_test, y_test = get_three_classes(x_test, y_test)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (15000, 32, 32, 3) (15000, 3)
# (3000, 32, 32, 3) (3000, 3)

# %% [markdown]
# # Task 3: Visualize Examples

# %%
class_names = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, 1+i)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'g' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        
        plt.xlabel(class_names[np.argmax(p[i])], color=col)
    plt.show()
    
show_random_examples(x_train, y_train, y_train)

# %%
show_random_examples(x_test, y_test, y_test)

# %% [markdown]
# # Task 4: Create Model

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense

def create_model():
    def add_conv_block(model, num_filters):
        model.add(Conv2D(num_filters, 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(Conv2D(num_filters, 3, activation='relu'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.5))
        return model
    
    model = tf.keras.models.Sequential()
    model.add(Input(shape=(32, 32, 3)))
    
    model = add_conv_block(model, 32)
    model = add_conv_block(model, 64)
    model = add_conv_block(model, 128)
    
    model.add(Flatten())
    model.add(Dense(3, activation='softmax'))
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam', 
        metrics=['accuracy']
    )
    
    return model
    
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 64)        256
# ...

# %% [markdown]
# # Task 5: Train the Model

# %%
h = model.fit(
    x_train/255.,
    y_train,
    validation_data=(x_test/255., y_test),
    epochs=10, batch_size=128,
    callbacks=[
#         if the validation accuracy does not imporve for 3 epochs stop the model fitting
#         then we'll change some hyper parameters and try again
        
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
#         saving the best fit model
        tf.keras.callbacks.ModelCheckpoint('models/model_{val_accuracy:.3f}.h5', save_best_only=True, 
                                           save_weights_only=False, monitor='val_accuracy')  
    ]
)
# Out:
# Train on 15000 samples, validate on 3000 samples
# Epoch 1/10
# 15000/15000 [==============================] - 135s 9ms/sample - loss: 0.8725 - accuracy: 0.6744 - val_loss: 3.1128 - val_accuracy: 0.3333
# Epoch 2/10
# 15000/15000 [==============================] - 130s 9ms/sample - loss: 0.5619 - accuracy: 0.7737 - val_loss: 2.7368 - val_accuracy: 0.3333
# Epoch 3/10
# 15000/15000 [==============================] - 131s 9ms/sample - loss: 0.4838 - accuracy: 0.8093 - val_loss: 2.0663 - val_accuracy: 0.4907
# Epoch 4/10
# 15000/15000 [==============================] - 131s 9ms/sample - loss: 0.4417 - accuracy: 0.8247 - val_loss: 1.1744 - val_accuracy: 0.6067
# Epoch 5/10
# 15000/15000 [==============================] - 131s 9ms/sample - loss: 0.4045 - accuracy: 0.8419 - val_loss: 0.4999 - val_accuracy: 0.8073
# Epoch 6/10
# 15000/15000 [==============================] - 132s 9ms/sample - loss: 0.3684 - accuracy: 0.8563 - val_loss: 0.4668 - val_accuracy: 0.8357
# Epoch 7/10
# ...

# %% [markdown]
# # Task 6: Final Predictions

# %%
acc = h.history['accuracy']
val_acc = h.history['val_accuracy']

no_of_epochs = 10

plt.plot(range(no_of_epochs), acc, label='Training')
plt.plot(range(no_of_epochs), val_acc, label='Validation')
plt.legend()
plt.show()

# %%
model = tf.keras.models.load_model('models/model_0.885.h5')

# %%
preds = model.predict(x_test/255.)

# %%
show_random_examples(x_test, y_test, preds)
